# %% [markdown]
# # model_001  –  KIER 에너지 예측 모델 진입점
#
# | 파일 | 모델 | 내용 |
# |---|---|---|
# | `model_dl_001.ipynb` | 1D CNN-LSTM / Seq2Seq | 단일 · 군집화 KFold CV · 비교 |
# | `model_ml_001.ipynb` | CB / XGB / LGBM / DT / RF | 단일 · KFold CV · 군집화 · 비교 |
#
# 파라미터(도메인·인터벌·K)는 각 노트북 **01. Init → Dict_Domain 셀** 에서 설정

# %% [markdown]
# ## 실행

# %%
## DL 모델 (1D CNN-LSTM / Seq2Seq) 실행
# %run 'model_dl_001.ipynb'

## ML 모델 (CB/XGB/LGBM/DT/RF) 실행
# %run 'model_ml_001.ipynb'
